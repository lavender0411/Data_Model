# %% [markdown]
# # Ordinal Regression with a Tabular Wine Quality Dataset
# #### Dataset from https://www.kaggle.com/competitions/playground-series-s3e5/overview

# %% [markdown]
# ## EDA

# %%
# visualize
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# model_selection
from sklearn.model_selection import StratifiedKFold, train_test_split

# model
import xgboost as xgb
# from xgboost import XGBClassifier

# optimize & measure tools
import optuna
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, accuracy_score

# warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# read csv
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
sample_submission = pd.read_csv('sample_submission.csv')

# %%
# 查看基本資料
print(train.shape, '\n')
print(train.head(), '\n')
print(train.isnull().sum(), '\n')
print(train.info(), '\n')
# Out:
# (2056, 13)
#
#    Id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   0            8.0              0.50         0.39             2.2
# 1   1            9.3              0.30         0.73             2.3
# 2   2            7.1              0.51         0.03             2.1
# 3   3            8.1              0.87         0.22             2.6
# 4   4            8.5              0.36         0.30             2.3
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.073                 30.0                  39.0  0.99572  3.33
# 1      0.092                 30.0                  67.0  0.99854  3.32
# 2      0.059                  3.0                  12.0  0.99660  3.52
# 3      0.084                 11.0                  65.0  0.99730  3.20
# 4      0.079                 10.0                  45.0  0.99444  3.20
#
#    sulphates  alcohol  quality
# 0       0.77     12.1        6
# 1       0.67     12.8        6
# 2       0.73     11.3        7
# 3       0.53      9.8        5
# 4       1.36      9.5        6
#
# Id                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2056 entries, 0 to 2055
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    2056 non-null   int64
#  1   fixed acidity         2056 non-null   float64
#  2   volatile acidity      2056 non-null   float64
#  3   citric acid           2056 non-null   float64
#  4   residual sugar        2056 non-null   float64
#  5   chlorides             2056 non-null   float64
#  6   free sulfur dioxide   2056 non-null   float64
#  7   total sulfur dioxide  2056 non-null   float64
#  8   density               2056 non-null   float64
#  9   pH                    2056 non-null   float64
#  10  sulphates             2056 non-null   float64
#  11  alcohol               2056 non-null   float64
#  12  quality               2056 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 208.9 KB
# None

# %%
# 查看相關性
sns.set_style("whitegrid")
plt.figure(figsize=(8, 6))
sns.heatmap(train.corr(), annot = True, fmt='.2f')

# 正相關
# citric acid vs fixed acidity 0.7 檸檬酸影響酸度
# total sulfur dioxide vs free sulfur dioxide 0.64 二氧化硫
# density vs fixed acidity 0.63 密度影響酸度
# quality vs alcohol 0.48 品質與酒精含量
# 負相關
# ph vs fixed acidity -0.67 酸度與 PH 值
# citric acid vs volatile acidity -0.59 酸度與揮發性酸
# volatile acidity vs quality -0.22 品質與揮發性酸
# total sulfur dioxide vs quality -0.23 品質與二氧化硫
# Out:
# <Axes: >

# %%
# 查看品質相關性
corr_q = train.corr()['quality'].sort_values()[:-1]
sns.barplot(corr_q, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# 查看數值分布
plt.figure(figsize = (14, 6))
plt.subplot(3, 4, 1)
sns.histplot(train['fixed acidity'], bins = 20)

plt.subplot(3, 4, 2)
sns.histplot(train['volatile acidity'], bins = 20)

plt.subplot(3, 4, 3)
sns.histplot(train['citric acid'], bins = 20)

plt.subplot(3, 4, 4)
sns.histplot(train['residual sugar'], bins = 20)

plt.subplot(3, 4, 5)
sns.histplot(train['chlorides'], bins = 20)

plt.subplot(3, 4, 6)
sns.histplot(train['free sulfur dioxide'], bins = 20)

plt.subplot(3, 4, 7)
sns.histplot(train['total sulfur dioxide'], bins = 20)

plt.subplot(3, 4, 8)
sns.histplot(train['density'], bins = 20)

plt.subplot(3, 4, 9)
sns.histplot(train['pH'], bins = 20)

plt.subplot(3, 4, 10)
sns.histplot(train['sulphates'], bins = 20)

plt.subplot(3, 4, 11)
sns.histplot(train['alcohol'], bins = 20)

plt.subplot(3, 4, 12)
sns.histplot(train['quality'], bins = 20)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Model

# %%
SEED = 42
NUM_FOLDS = 10

X = train.drop(['quality', 'Id'], axis = 1)
y = train['quality']

testing = test.drop('Id', axis = 1)

# %%
# 參數選擇
def objective_class(trial, train = X, target = y):
    
    le = LabelEncoder()

    # 使數據平衡平均分配
    kf = StratifiedKFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
    
    params = {
        'random_state': SEED,
        'nthread': -1, 
        'objective': 'multi:softmax',
        'num_class': 10,
        
        'eta': trial.suggest_float('eta', 0, 1),
        'gamma': trial.suggest_float('gamma', 0, 20),  
        'max_depth': trial.suggest_int('max_depth', 0, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 0, 30), 
        'max_delta_step': trial.suggest_float('max_delta_step', 0, 30),
        'subsample': trial.suggest_float('subsample', 0, 1), 
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0, 1), 
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0, 2), 
        'lambda': trial.suggest_float('lambda', 0, 50), 
        'alpha': trial.suggest_float('alpha', 0, 50), 
     }
    
    scores = []
    
    for f, (train_idx, val_idx) in enumerate(kf.split(train, target)):
        
        train_df, val_df = train.iloc[train_idx], train.iloc[val_idx]
        train_target, val_target = target[train_idx], target[val_idx]
        
        
        y_train_code = le.fit_transform(train_target)
        y_test_code = le.fit_transform(val_target)

        trn_data = xgb.DMatrix(train_df, y_train_code)
        val_data = xgb.DMatrix(val_df, y_test_code)



        model = xgb.train(params, trn_data, num_boost_round=100,
                          evals=[(val_data, 'val_data')], verbose_eval=False, early_stopping_rounds=10)

        val_pred_data_class = model.predict(val_data)

        scores.append(accuracy_score(le.inverse_transform(val_pred_data_class.astype(int)), val_target))
        
    return np.mean(scores)

study = optuna.create_study(direction='maximize')
study.optimize(objective_class, n_trials = 50)

print('Best trial parameters:', study.best_params)
print('Best score:', study.best_value)
# Out:
# [I 2025-05-22 16:44:46,244] A new study created in memory with name: no-name-5717b81d-2436-42b1-9a0e-c7bee94b41e6
# [I 2025-05-22 16:44:47,490] Trial 0 finished with value: 0.5350295998105612 and parameters: {'eta': 0.9883636873177069, 'gamma': 15.979026014911293, 'max_depth': 1, 'min_child_weight': 2, 'max_delta_step': 9.123635050045488, 'subsample': 0.6647351774924048, 'colsample_bytree': 0.5477732112346752, 'scale_pos_weight': 0.21500553811071232, 'lambda': 17.90189815235199, 'alpha': 22.753490602502346}. Best is trial 0 with value: 0.5350295998105612.
# [I 2025-05-22 16:44:48,810] Trial 1 finished with value: 0.5413189675586076 and parameters: {'eta': 0.16417812455865455, 'gamma': 2.8291862842894755, 'max_depth': 10, 'min_child_weight': 26, 'max_delta_step': 12.467529878919128, 'subsample': 0.12331597403978711, 'colsample_bytree': 0.7645221345215173, 'scale_pos_weight': 1.7491188537779672, 'lambda': 0.2975568899419967, 'alpha': 36.49850090568744}. Best is trial 1 with value: 0.5413189675586076.
# [I 2025-05-22 16:44:49,809] Trial 2 finished with value: 0.5739261188728392 and parameters: {'eta': 0.17692559469455338, 'gamma': 2.2192238516786245, 'max_depth': 5, 'min_child_weight': 25, 'max_delta_step': 4.885914702560584, 'subsample': 0.7930916228101844, 'colsample_bytree': 0.05410872292590474, 'scale_pos_weight': 0.7152645688659471, 'lambda': 3.562704466504246, 'alpha': 19.09576525820494}. Best is trial 2 with value: 0.5739261188728392.
# [I 2025-05-22 16:44:50,880] Trial 3 finished with value: 0.5617570447549136 and parameters: {'eta': 0.34963716794890387, 'gamma': 14.063173917126107, 'max_depth': 3, 'min_child_weight': 10, 'max_delta_step': 18.844007326450885, 'subsample': 0.3564336867463984, 'colsample_bytree': 0.043370431251843145, 'scale_pos_weight': 0.14943850458898456, 'lambda': 47.50140382989736, 'alpha': 43.43669710908312}. Best is trial 2 with value: 0.5739261188728392.
# [I 2025-05-22 16:44:51,754] Trial 4 finished with value: 0.5282169074117926 and parameters: {'eta': 0.8328368261182184, 'gamma': 18.64681542876085, 'max_depth': 4, 'min_child_weight': 21, 'max_delta_step': 12.335802957482704, 'subsample': 0.13414507878523374, 'colsample_bytree': 0.13093157444480086, 'scale_pos_weight': 0.3837183369582511, 'lambda': 6.77732478832131, 'alpha': 16.74224886177973}. Best is trial 2 with value: 0.5739261188728392.
# [I 2025-05-22 16:44:52,800] Trial 5 finished with value: 0.5554392611887284 and parameters: {'eta': 0.8883865116881453, 'gamma': 15.461205287305999, 'max_depth': 4, 'min_child_weight': 15, 'max_delta_step': 19.80061736296261, 'subsample': 0.6883134396576355, 'colsample_bytree': 0.663804481649002, 'scale_pos_weight': 1.229981253428012, 'lambda': 20.972107288441677, 'alpha': 24.697682291782286}. Best is trial 2 with value: 0.5739261188728392.
# [I 2025-05-22 16:44:52,965] Trial 6 finished with value: 0.005834714657826189 and parameters: {'eta': 0.8671486099379367, 'gamma': 13.63510069128743, 'max_depth': 7, 'min_child_weight': 13, 'max_delta_step': 0.8836869248583579, 'subsample': 0.009543493704790795, 'colsample_bytree': 0.1787048347117418, 'scale_pos_weight': 0.7456687173818404, 'lambda': 42.16144022230868, 'alpha': 38.50662426891277}. Best is trial 2 with value: 0.5739261188728392.
# [I 2025-05-22 16:44:54,310] Trial 7 finished with value: 0.561288183755624 and parameters: {'eta': 0.2806773814645307, 'gamma': 14.450170198025141, 'max_depth': 6, 'min_child_weight': 2, 'max_delta_step': 22.386738683630963, 'subsample': 0.4805887824149718, 'colsample_bytree': 0.5904570428287051, 'scale_pos_weight': 0.45626069435855743, 'lambda': 9.749769695801064, 'alpha': 32.67624351282353}. Best is trial 2 with value: 0.5739261188728392.
# [I 2025-05-22 16:44:55,240] Trial 8 finished with value: 0.5627302865261662 and parameters: {'eta': 0.9952715231021834, 'gamma': 1.858481141705306, 'max_depth': 4, 'min_child_weight': 23, 'max_delta_step': 27.112441397507368, 'subsample': 0.7294232600704834, 'colsample_bytree': 0.40911727362292793, 'scale_pos_weight': 1.3979462996371885, 'lambda': 21.75185405972418, 'alpha': 39.46778082264532}. Best is trial 2 with value: 0.5739261188728392.
# [I 2025-05-22 16:44:56,526] Trial 9 finished with value: 0.5865877338385034 and parameters: {'eta': 0.22561170986130885, 'gamma': 1.9670466800236763, 'max_depth': 0, 'min_child_weight': 5, 'max_delta_step': 8.574120457878387, 'subsample': 0.4981275402921387, 'colsample_bytree': 0.39741597689682373, 'scale_pos_weight': 0.6598293648102131, 'lambda': 44.35673484812233, 'alpha': 3.965087753467306}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:44:57,747] Trial 10 finished with value: 0.5719914752545583 and parameters: {'eta': 0.5273168226231744, 'gamma': 7.704492005076799, 'max_depth': 0, 'min_child_weight': 7, 'max_delta_step': 7.2333064352936125, 'subsample': 0.9638317516052326, 'colsample_bytree': 0.983644825859984, 'scale_pos_weight': 1.9309230727811215, 'lambda': 34.82563499143955, 'alpha': 1.4127209249894896}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:44:59,257] Trial 11 finished with value: 0.5773336490646459 and parameters: {'eta': 0.029981802013779757, 'gamma': 6.3455297316441595, 'max_depth': 8, 'min_child_weight': 19, 'max_delta_step': 2.141817496514662, 'subsample': 0.9897072792628456, 'colsample_bytree': 0.32925562988787516, 'scale_pos_weight': 0.8266161562137497, 'lambda': 32.41534420974251, 'alpha': 5.594819267249093}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:02,580] Trial 12 finished with value: 0.5744210277054226 and parameters: {'eta': 0.016474078854461307, 'gamma': 6.730652855376629, 'max_depth': 9, 'min_child_weight': 19, 'max_delta_step': 1.090942422040639, 'subsample': 0.3829429829259646, 'colsample_bytree': 0.30641494417942144, 'scale_pos_weight': 0.8994994954696076, 'lambda': 32.859025597705596, 'alpha': 2.754139427719261}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:08,146] Trial 13 finished with value: 0.5787852237745679 and parameters: {'eta': 0.03642983594896973, 'gamma': 5.906474104314295, 'max_depth': 8, 'min_child_weight': 30, 'max_delta_step': 5.195573311151311, 'subsample': 0.9875867987157673, 'colsample_bytree': 0.33521378535657437, 'scale_pos_weight': 1.2056787928214838, 'lambda': 33.171295387469, 'alpha': 10.141750645996535}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:14,097] Trial 14 finished with value: 0.5826947667534926 and parameters: {'eta': 0.5068574634506359, 'gamma': 0.02895125781487584, 'max_depth': 1, 'min_child_weight': 30, 'max_delta_step': 8.924487758853278, 'subsample': 0.5422768859646463, 'colsample_bytree': 0.4056645265659986, 'scale_pos_weight': 1.1970803345632848, 'lambda': 49.914451111482585, 'alpha': 11.265513106144805}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:15,291] Trial 15 finished with value: 0.5860975609756098 and parameters: {'eta': 0.577076759904564, 'gamma': 0.3021818182892653, 'max_depth': 2, 'min_child_weight': 11, 'max_delta_step': 14.554842582561813, 'subsample': 0.5529840272544297, 'colsample_bytree': 0.44463632096811867, 'scale_pos_weight': 1.5416593487222685, 'lambda': 45.457021796438084, 'alpha': 12.365421348040094}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:16,947] Trial 16 finished with value: 0.5549514563106795 and parameters: {'eta': 0.6482154711280175, 'gamma': 10.954831338228308, 'max_depth': 2, 'min_child_weight': 7, 'max_delta_step': 15.670561786535176, 'subsample': 0.3094187242960593, 'colsample_bytree': 0.7608589437253214, 'scale_pos_weight': 1.569704359479405, 'lambda': 41.42085867932287, 'alpha': 11.949885816349628}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:18,220] Trial 17 finished with value: 0.5768742600047359 and parameters: {'eta': 0.6397361751840592, 'gamma': 0.051645027001014476, 'max_depth': 0, 'min_child_weight': 6, 'max_delta_step': 14.562442629608022, 'subsample': 0.5261553261690219, 'colsample_bytree': 0.46580034947163873, 'scale_pos_weight': 0.5942320089196625, 'lambda': 42.23857837599364, 'alpha': 7.047890835871395}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:19,637] Trial 18 finished with value: 0.5724698081932275 and parameters: {'eta': 0.3965042318690362, 'gamma': 3.9012219989356263, 'max_depth': 2, 'min_child_weight': 13, 'max_delta_step': 29.0924028166858, 'subsample': 0.5874275539776529, 'colsample_bytree': 0.2712535448057596, 'scale_pos_weight': 1.573750536711004, 'lambda': 39.49497802839402, 'alpha': 29.415809247527754}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:20,810] Trial 19 finished with value: 0.5612787118162443 and parameters: {'eta': 0.6914985534872802, 'gamma': 10.022795151655096, 'max_depth': 2, 'min_child_weight': 0, 'max_delta_step': 11.024310990913222, 'subsample': 0.8377914035920536, 'colsample_bytree': 0.20682139303578495, 'scale_pos_weight': 1.0260611976327205, 'lambda': 27.10450441460782, 'alpha': 49.698134452320076}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:22,205] Trial 20 finished with value: 0.5768529481411317 and parameters: {'eta': 0.4472273269131116, 'gamma': 4.705634587424912, 'max_depth': 0, 'min_child_weight': 10, 'max_delta_step': 17.16272602563711, 'subsample': 0.4223943801433265, 'colsample_bytree': 0.6526914060885136, 'scale_pos_weight': 1.94664110101345, 'lambda': 46.80563639401947, 'alpha': 15.801753584021988}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:23,581] Trial 21 finished with value: 0.5856121240824057 and parameters: {'eta': 0.5232998987237002, 'gamma': 0.13216672004225494, 'max_depth': 1, 'min_child_weight': 4, 'max_delta_step': 8.61629577727102, 'subsample': 0.6081587075478829, 'colsample_bytree': 0.43685867492260183, 'scale_pos_weight': 1.2446235658403526, 'lambda': 49.756714546246, 'alpha': 12.192396703738535}. Best is trial 9 with value: 0.5865877338385034.
# [I 2025-05-22 16:45:25,898] Trial 22 finished with value: 0.5895169310916409 and parameters: {'eta': 0.5742068865072524, 'gamma': 1.1202676623232228, 'max_depth': 1, 'min_child_weight': 4, 'max_delta_step': 6.033149606104429, 'subsample': 0.6155799759561141, 'colsample_bytree': 0.4767910942087683, 'scale_pos_weight': 1.4289602778545099, 'lambda': 46.925972265633376, 'alpha': 6.741116905317568}. Best is trial 22 with value: 0.5895169310916409.
# [I 2025-05-22 16:45:27,047] Trial 23 finished with value: 0.5909685058015628 and parameters: {'eta': 0.7386986532971423, 'gamma': 1.5668997020351147, 'max_depth': 3, 'min_child_weight': 10, 'max_delta_step': 3.9797466900005007, 'subsample': 0.2647506056329342, 'colsample_bytree': 0.5264758889838429, 'scale_pos_weight': 1.5124568473774749, 'lambda': 38.83723376246942, 'alpha': 6.609258759866072}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:28,047] Trial 24 finished with value: 0.5841652853421737 and parameters: {'eta': 0.7457975129557407, 'gamma': 3.60638528555356, 'max_depth': 3, 'min_child_weight': 5, 'max_delta_step': 5.047035405745111, 'subsample': 0.26838987646092316, 'colsample_bytree': 0.5398297370390218, 'scale_pos_weight': 1.394096961825147, 'lambda': 37.842728531201004, 'alpha': 5.686471754787526}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:29,491] Trial 25 finished with value: 0.5666279895808668 and parameters: {'eta': 0.7296100219869076, 'gamma': 8.119223977927527, 'max_depth': 3, 'min_child_weight': 9, 'max_delta_step': 4.7879048320521775, 'subsample': 0.23592147178639067, 'colsample_bytree': 0.6355191597627065, 'scale_pos_weight': 1.7221548768068529, 'lambda': 28.42576486201187, 'alpha': 1.2502166057940594}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:30,245] Trial 26 finished with value: 0.5875491356855316 and parameters: {'eta': 0.7828078170294245, 'gamma': 1.8650691449780659, 'max_depth': 1, 'min_child_weight': 3, 'max_delta_step': 7.475318608564984, 'subsample': 0.4509119541840674, 'colsample_bytree': 0.7664477553011356, 'scale_pos_weight': 0.9437518374419571, 'lambda': 36.85530703856898, 'alpha': 6.193922105059172}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:31,715] Trial 27 finished with value: 0.5739261188728392 and parameters: {'eta': 0.7997907073350937, 'gamma': 4.1320926870404655, 'max_depth': 1, 'min_child_weight': 0, 'max_delta_step': 2.7176023757461185, 'subsample': 0.2034717942211355, 'colsample_bytree': 0.951357664839246, 'scale_pos_weight': 1.0226624222440672, 'lambda': 37.02161628146884, 'alpha': 19.39509580116313}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:33,088] Trial 28 finished with value: 0.5637366800852475 and parameters: {'eta': 0.6281344946219692, 'gamma': 11.715043402569048, 'max_depth': 5, 'min_child_weight': 8, 'max_delta_step': 6.451619474650807, 'subsample': 0.4665289008687112, 'colsample_bytree': 0.8673983711418009, 'scale_pos_weight': 1.3601652956884411, 'lambda': 29.62004948856259, 'alpha': 9.258237141791724}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:34,635] Trial 29 finished with value: 0.5652095666587733 and parameters: {'eta': 0.9259528430494822, 'gamma': 4.967256856352846, 'max_depth': 1, 'min_child_weight': 3, 'max_delta_step': 10.72828385680033, 'subsample': 0.6256747986856943, 'colsample_bytree': 0.727343987323669, 'scale_pos_weight': 1.030949443146029, 'lambda': 12.887988174021379, 'alpha': 22.285116374910494}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:36,395] Trial 30 finished with value: 0.5880511484726497 and parameters: {'eta': 0.7742202733907793, 'gamma': 1.3264866279595127, 'max_depth': 3, 'min_child_weight': 16, 'max_delta_step': 2.6718937682328194, 'subsample': 0.32750437431662205, 'colsample_bytree': 0.8567958216293714, 'scale_pos_weight': 1.7455244198883055, 'lambda': 37.07550939387364, 'alpha': 15.729292835895787}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:37,880] Trial 31 finished with value: 0.5904854368932039 and parameters: {'eta': 0.7714003435562886, 'gamma': 1.6317603920463253, 'max_depth': 3, 'min_child_weight': 16, 'max_delta_step': 3.383856170359194, 'subsample': 0.3381733914672639, 'colsample_bytree': 0.852804062014635, 'scale_pos_weight': 1.7389441916414108, 'lambda': 37.4476564070342, 'alpha': 14.583148068365176}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:39,268] Trial 32 finished with value: 0.5685792090930617 and parameters: {'eta': 0.7052897237762814, 'gamma': 3.008967507533254, 'max_depth': 3, 'min_child_weight': 17, 'max_delta_step': 3.3783978570812, 'subsample': 0.15624783527903227, 'colsample_bytree': 0.8925017216381823, 'scale_pos_weight': 1.733714805210675, 'lambda': 39.80134629033947, 'alpha': 13.703683766314333}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:40,991] Trial 33 finished with value: 0.5637319441155576 and parameters: {'eta': 0.9285438093106319, 'gamma': 0.9935090053427746, 'max_depth': 4, 'min_child_weight': 16, 'max_delta_step': 0.0198673882967908, 'subsample': 0.32409646474027526, 'colsample_bytree': 0.8246181993124282, 'scale_pos_weight': 1.8687303993442348, 'lambda': 31.105376296292167, 'alpha': 20.398677921237994}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:42,419] Trial 34 finished with value: 0.553999526403031 and parameters: {'eta': 0.5831901569242788, 'gamma': 2.761567478049618, 'max_depth': 5, 'min_child_weight': 13, 'max_delta_step': 4.1369639296430085, 'subsample': 0.07296932771621828, 'colsample_bytree': 0.567655608366757, 'scale_pos_weight': 1.8228264907018636, 'lambda': 25.024758315352557, 'alpha': 16.72734088557263}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:43,671] Trial 35 finished with value: 0.5457186834004263 and parameters: {'eta': 0.7958830996905633, 'gamma': 19.54504296130675, 'max_depth': 3, 'min_child_weight': 18, 'max_delta_step': 2.211311801124202, 'subsample': 0.3993204566502123, 'colsample_bytree': 0.5077090780810626, 'scale_pos_weight': 1.6371648684679518, 'lambda': 43.633527442093666, 'alpha': 0.0245372251165783}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:44,718] Trial 36 finished with value: 0.5856144920672507 and parameters: {'eta': 0.6768627840736283, 'gamma': 1.657934746144731, 'max_depth': 2, 'min_child_weight': 15, 'max_delta_step': 5.922360742869108, 'subsample': 0.3180487954911828, 'colsample_bytree': 0.91310909218685, 'scale_pos_weight': 1.4898387021709827, 'lambda': 35.261828787402735, 'alpha': 8.897735375673344}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:45,837] Trial 37 finished with value: 0.5676035993369642 and parameters: {'eta': 0.8467408732665301, 'gamma': 5.3974807049915485, 'max_depth': 6, 'min_child_weight': 12, 'max_delta_step': 10.46445089843007, 'subsample': 0.24731617758027924, 'colsample_bytree': 0.8268490493131183, 'scale_pos_weight': 1.7098757861034664, 'lambda': 16.502771785864162, 'alpha': 15.009399839836515}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:46,944] Trial 38 finished with value: 0.5233459625858394 and parameters: {'eta': 0.5945374182228036, 'gamma': 17.379488930843422, 'max_depth': 4, 'min_child_weight': 21, 'max_delta_step': 3.2396524961685267, 'subsample': 0.1743847690289848, 'colsample_bytree': 0.7007300656123207, 'scale_pos_weight': 1.9926744454250165, 'lambda': 47.27823473778009, 'alpha': 25.457925767732817}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:48,166] Trial 39 finished with value: 0.5754155813402793 and parameters: {'eta': 0.9228006419992103, 'gamma': 3.214194424504937, 'max_depth': 5, 'min_child_weight': 15, 'max_delta_step': 1.061866587742816, 'subsample': 0.28069252754162816, 'colsample_bytree': 0.6165077092183475, 'scale_pos_weight': 1.4501352387898323, 'lambda': 39.72127533843044, 'alpha': 17.987350587979098}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:49,269] Trial 40 finished with value: 0.5647051858868103 and parameters: {'eta': 0.7543881755800432, 'gamma': 1.2756633042378296, 'max_depth': 3, 'min_child_weight': 21, 'max_delta_step': 12.573895657987935, 'subsample': 0.35504520703760034, 'colsample_bytree': 0.09384781963177413, 'scale_pos_weight': 1.8212920027342745, 'lambda': 1.8431409157557077, 'alpha': 22.843819804824694}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:50,298] Trial 41 finished with value: 0.5724887520719866 and parameters: {'eta': 0.7909063221458145, 'gamma': 2.4426294469585175, 'max_depth': 2, 'min_child_weight': 2, 'max_delta_step': 7.612121841633603, 'subsample': 0.432036044542758, 'colsample_bytree': 0.7979848196089874, 'scale_pos_weight': 1.3265105838913476, 'lambda': 36.36520046211983, 'alpha': 7.132447415088757}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:51,052] Trial 42 finished with value: 0.5783187307601232 and parameters: {'eta': 0.8785272910447067, 'gamma': 1.5195007654105697, 'max_depth': 4, 'min_child_weight': 9, 'max_delta_step': 6.871395174905736, 'subsample': 0.6885747312978054, 'colsample_bytree': 0.7566854614032055, 'scale_pos_weight': 1.6465679543293144, 'lambda': 38.2383950739889, 'alpha': 4.650953268611826}. Best is trial 23 with value: 0.5909685058015628.
# [I 2025-05-22 16:45:52,310] Trial 43 finished with value: 0.5919441155576604 and parameters: {'eta': 0.8279733156022024, 'gamma': 1.2805731324282872, 'max_depth': 1, 'min_child_weight': 2, 'max_delta_step': 4.227009567951404, 'subsample': 0.4663349745367772, 'colsample_bytree': 0.9957915520589915, 'scale_pos_weight': 1.137162567328994, 'lambda': 42.3663585395093, 'alpha': 7.956754150743961}. Best is trial 43 with value: 0.5919441155576604.
# [I 2025-05-22 16:45:54,087] Trial 44 finished with value: 0.5647099218565002 and parameters: {'eta': 0.8386159065165235, 'gamma': 1.1078829925661315, 'max_depth': 0, 'min_child_weight': 11, 'max_delta_step': 3.778943726160101, 'subsample': 0.08698425098476792, 'colsample_bytree': 0.9980892057832982, 'scale_pos_weight': 1.1062646779204668, 'lambda': 43.25876204785465, 'alpha': 8.812485725521102}. Best is trial 43 with value: 0.5919441155576604.
# [I 2025-05-22 16:45:55,247] Trial 45 finished with value: 0.5758962822637934 and parameters: {'eta': 0.9777679243067101, 'gamma': 2.443189822784739, 'max_depth': 2, 'min_child_weight': 24, 'max_delta_step': 23.902200015324148, 'subsample': 0.7715758004066868, 'colsample_bytree': 0.9539438536442298, 'scale_pos_weight': 0.036020050612469934, 'lambda': 45.18815616093238, 'alpha': 14.408737784472791}. Best is trial 43 with value: 0.5919441155576604.
# [I 2025-05-22 16:45:56,603] Trial 46 finished with value: 0.5812266161496566 and parameters: {'eta': 0.7176021451072607, 'gamma': 4.49853475676144, 'max_depth': 6, 'min_child_weight': 1, 'max_delta_step': 1.9931397044348045, 'subsample': 0.3690818685985944, 'colsample_bytree': 0.863894580050574, 'scale_pos_weight': 1.2973989202034424, 'lambda': 40.570053043513006, 'alpha': 3.4062726255370763}. Best is trial 43 with value: 0.5919441155576604.
# [I 2025-05-22 16:45:57,810] Trial 47 finished with value: 0.589514563106796 and parameters: {'eta': 0.8226975680925306, 'gamma': 0.8242779300229306, 'max_depth': 10, 'min_child_weight': 14, 'max_delta_step': 0.1149257527875247, 'subsample': 0.4940102003045035, 'colsample_bytree': 0.9296638338727045, 'scale_pos_weight': 1.639218270788247, 'lambda': 48.260432149424254, 'alpha': 7.817798974405928}. Best is trial 43 with value: 0.5919441155576604.
# [I 2025-05-22 16:45:59,304] Trial 48 finished with value: 0.5705541084537058 and parameters: {'eta': 0.8352243245249366, 'gamma': 7.083643240389895, 'max_depth': 7, 'min_child_weight': 13, 'max_delta_step': 5.668711954338439, 'subsample': 0.6536498217900937, 'colsample_bytree': 0.9633060960736588, 'scale_pos_weight': 1.1329127012806068, 'lambda': 48.479887925844, 'alpha': 8.039263819691865}. Best is trial 43 with value: 0.5919441155576604.
# [I 2025-05-22 16:46:00,704] Trial 49 finished with value: 0.5797726734548899 and parameters: {'eta': 0.4416585885400524, 'gamma': 3.4594877000607633, 'max_depth': 7, 'min_child_weight': 6, 'max_delta_step': 4.275792534304098, 'subsample': 0.5114010164392658, 'colsample_bytree': 0.9233485355790059, 'scale_pos_weight': 1.4861271568477674, 'lambda': 45.80111349460991, 'alpha': 2.7526265794341356}. Best is trial 43 with value: 0.5919441155576604.
# Best trial parameters: {'eta': 0.8279733156022024, 'gamma': 1.2805731324282872, 'max_depth': 1, 'min_child_weight': 2, 'max_delta_step': 4.227009567951404, 'subsample': 0.4663349745367772, 'colsample_bytree': 0.9957915520589915, 'scale_pos_weight': 1.137162567328994, 'lambda': 42.3663585395093, 'alpha': 7.956754150743961}
# Best score: 0.5919441155576604

# %%
# 模型預測
def model_predict_class(train = X, target = y, test = testing):
    
    # 使數據平衡平均分配
    kf = StratifiedKFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
    
    params = {
        'random_state': SEED,
        'nthread': -1, 
        'objective': 'multi:softmax',
        'num_class': 10,
        
        'eta': 0.8279733156022024, 
        'gamma': 1.2805731324282872, 
        'max_depth': 1, 'min_child_weight': 2, 
        'max_delta_step': 4.227009567951404, 
        'subsample': 0.4663349745367772, 
        'colsample_bytree': 0.9957915520589915, 
        'scale_pos_weight': 1.137162567328994, 
        'lambda': 42.3663585395093, 
        'alpha': 7.956754150743961
    }

    trn_data = xgb.DMatrix(train, label=target)
    test_data = xgb.DMatrix(test)

    model = xgb.train(params, trn_data, num_boost_round=100, verbose_eval=False)

    pred_data = model.predict(test_data)
        
    return pred_data

pred_data = model_predict_class()
# Out:
# array([6., 6., 5., ..., 5., 5., 5.], dtype=float32)

# %%
# 匯出 submission
sample_submission['quality'] = val_pred_data.round().astype(int)
sample_submission.to_csv('subsci_df_class.csv', index=False)
sample_submission
# Out:
#         Id  quality
# 0     2056        6
# 1     2057        6
# 2     2058        5
# 3     2059        6
# 4     2060        5
# ...    ...      ...
# 1367  3423        5
# 1368  3424        7
# 1369  3425        5
# 1370  3426        5
# 1371  3427        5
#
# [1372 rows x 2 columns]

# %% [markdown]
# ### 其他：使用 XGBClassifier

# %%
# XGBClassifier
def model_predict_classifier(train = X, target = y, test = testing):

    le = LabelEncoder()

    test_pred = 0
    scores = []


    kf = StratifiedKFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)

    for f, (train_idx, val_idx) in enumerate(kf.split(train, target)):

        X_train, X_test = train.iloc[train_idx], train.iloc[val_idx]
        y_train, y_test = target[train_idx], target[val_idx]

        y_train_code = le.fit_transform(y_train)
        y_test_code = le.fit_transform(y_test)

        xgb_clf = xgb.XGBClassifier(
            n_estimators = 500,
            learning_rate = 0.05,
            eval_metric = "mlogloss")

        xgb_clf.fit(X_train, y_train_code, verbose = False)

        pred_data = xgb_clf.predict(X_test)

        scores.append(accuracy_score(y_test, le.inverse_transform(pred_data)))

        test_pred += le.inverse_transform(xgb_clf.predict(test))/NUM_FOLDS

    return test_pred, np.mean(scores)

test_pred, scores = model_predict_classifier()

sample_submission['quality'] = test_pred.astype(int)
sample_submission.to_csv('subsci_df_classifier.csv', index=False)
sample_submission
# Out:
# test_pred :  [6.  6.4 6.  ... 5.2 5.  5.2]
# scores :  0.5598413450153918
#         Id  quality
# 0     2056        5
# 1     2057        6
# 2     2058        5
# 3     2059        5
# 4     2060        5
# ...    ...      ...
# 1367  3423        5
# 1368  3424        6
# 1369  3425        5
# 1370  3426        5
# 1371  3427        5
#
# [1372 rows x 2 columns]

# %% [markdown]
# ### 其他：使用 regression

# %%
def objective_reg(trial, train = X, target = y):
    
    # 使數據平衡平均分配
    kf = StratifiedKFold(n_splits=num_folds, random_state=SEED, shuffle=True)
    
    params = {
        'eta': trial.suggest_float('eta', 0, 1),
        'gamma': trial.suggest_float('gamma', 0, 20), 
        'max_depth': trial.suggest_int('max_depth', 0, 10), 
        'min_child_weight': trial.suggest_int('min_child_weight', 0, 30), 
        'max_delta_step': trial.suggest_float('max_delta_step', 0, 30),
        'subsample': trial.suggest_float('subsample', 0, 1), 
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0, 1), 
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 0, 2), 
        'lambda': trial.suggest_float('lambda', 0, 50), 
        'alpha': trial.suggest_float('alpha', 0, 50), 
     }
    
    scores = []
    
    for f, (train_idx, val_idx) in enumerate(kf.split(train, target)):
        
        train_df, val_df = train.iloc[train_idx], train.iloc[val_idx]
        train_target, val_target = target[train_idx], target[val_idx]

        trn_data = xgb.DMatrix(train_df, train_target)
        val_data = xgb.DMatrix(val_df, val_target)
        test_data = xgb.DMatrix(test)

        model = xgb.train(params, trn_data, num_boost_round=1000,
                          evals=[(val_data, 'val_data')], verbose_eval=False, early_stopping_rounds=10)

        val_pred_data = model.predict(val_data)
        
        
        scores.append(mean_squared_error(val_target, val_pred_data.round().astype('int')))
        
    return np.mean(scores)

study = optuna.create_study(direction='minimize')
study.optimize(objective_reg, n_trials = 50)

print('Best trial parameters:', study.best_params)
print('Best score:', study.best_value)
# Out:
# [I 2025-05-21 17:10:33,890] A new study created in memory with name: no-name-0429d7fa-0c21-4fde-8d09-ddb13d04bb3e
# [I 2025-05-21 17:10:34,129] Trial 0 finished with value: 0.5725171678901255 and parameters: {'eta': 0.8095471019273717, 'gamma': 16.839521195672152, 'max_depth': 7, 'min_child_weight': 26, 'max_delta_step': 23.135009684290665, 'subsample': 0.8731608408459289, 'colsample_bytree': 0.6147258405724056, 'scale_pos_weight': 0.6326305570145407, 'lambda': 12.063739419053693, 'alpha': 22.153480086279163}. Best is trial 0 with value: 0.5725171678901255.
# [I 2025-05-21 17:10:34,341] Trial 1 finished with value: 0.5579138053516457 and parameters: {'eta': 0.18670580970367767, 'gamma': 15.840590838251401, 'max_depth': 9, 'min_child_weight': 19, 'max_delta_step': 23.49288380625215, 'subsample': 0.5701910113078524, 'colsample_bytree': 0.5898212988933997, 'scale_pos_weight': 1.219034386443866, 'lambda': 46.17482626622085, 'alpha': 21.77885211702216}. Best is trial 1 with value: 0.5579138053516457.
# [I 2025-05-21 17:10:34,689] Trial 2 finished with value: 0.5583992422448496 and parameters: {'eta': 0.0662519163475187, 'gamma': 12.235672291898565, 'max_depth': 3, 'min_child_weight': 5, 'max_delta_step': 17.50559434408149, 'subsample': 0.7676245776332543, 'colsample_bytree': 0.8910500823993773, 'scale_pos_weight': 1.7732654792374558, 'lambda': 36.043989559397836, 'alpha': 45.52095363060287}. Best is trial 1 with value: 0.5579138053516457.
# [I 2025-05-21 17:10:34,811] Trial 3 finished with value: 0.5501136632725551 and parameters: {'eta': 0.7470868529073513, 'gamma': 17.513377292292162, 'max_depth': 5, 'min_child_weight': 23, 'max_delta_step': 3.6441069956694125, 'subsample': 0.6085320340288892, 'colsample_bytree': 0.2522009428066263, 'scale_pos_weight': 0.1339900687424156, 'lambda': 35.86112958012374, 'alpha': 49.477967837849796}. Best is trial 3 with value: 0.5501136632725551.
# [I 2025-05-21 17:10:34,948] Trial 4 finished with value: 0.37840397821453936 and parameters: {'eta': 0.40623781973319983, 'gamma': 6.0419986957095055, 'max_depth': 5, 'min_child_weight': 10, 'max_delta_step': 11.710459828187522, 'subsample': 0.14002301709572773, 'colsample_bytree': 0.46761357836748774, 'scale_pos_weight': 1.937822384427298, 'lambda': 31.268257820037277, 'alpha': 47.91599175107431}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:35,079] Trial 5 finished with value: 0.5661899123845607 and parameters: {'eta': 0.7815675540773674, 'gamma': 18.51334995497789, 'max_depth': 10, 'min_child_weight': 14, 'max_delta_step': 29.074356130630495, 'subsample': 0.9409803337723504, 'colsample_bytree': 0.4512445256646973, 'scale_pos_weight': 0.236804335884371, 'lambda': 10.119046555076356, 'alpha': 31.588201933642644}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:35,227] Trial 6 finished with value: 0.5014610466493015 and parameters: {'eta': 0.6289949771396492, 'gamma': 7.280996689536138, 'max_depth': 10, 'min_child_weight': 26, 'max_delta_step': 1.446736256625597, 'subsample': 0.972402007030583, 'colsample_bytree': 0.1206590573379811, 'scale_pos_weight': 1.5756068652590232, 'lambda': 26.472124789239725, 'alpha': 19.237735578245395}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:35,349] Trial 7 finished with value: 0.3900544636514326 and parameters: {'eta': 0.9480875410898033, 'gamma': 5.039576417164731, 'max_depth': 1, 'min_child_weight': 16, 'max_delta_step': 10.779779379292998, 'subsample': 0.0971211071414757, 'colsample_bytree': 0.01104108247191593, 'scale_pos_weight': 1.1930622995533886, 'lambda': 11.674304326050395, 'alpha': 18.51212486514703}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:35,656] Trial 8 finished with value: 0.5398721288183757 and parameters: {'eta': 0.23567472423254943, 'gamma': 2.5599605668746706, 'max_depth': 1, 'min_child_weight': 29, 'max_delta_step': 6.979488153020093, 'subsample': 0.3368203061410565, 'colsample_bytree': 0.08825324361656794, 'scale_pos_weight': 1.5841833413183772, 'lambda': 25.15098943201311, 'alpha': 12.826400931627497}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:35,788] Trial 9 finished with value: 0.5549775041439734 and parameters: {'eta': 0.7313241777162498, 'gamma': 9.697879870527373, 'max_depth': 1, 'min_child_weight': 22, 'max_delta_step': 17.022030419341096, 'subsample': 0.8274963181251701, 'colsample_bytree': 0.25230042241834527, 'scale_pos_weight': 1.1850482798269173, 'lambda': 11.506348429693357, 'alpha': 33.97888495544373}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:35,957] Trial 10 finished with value: 0.37840397821453936 and parameters: {'eta': 0.42370545938172993, 'gamma': 0.5771357951600562, 'max_depth': 5, 'min_child_weight': 0, 'max_delta_step': 11.324567618264178, 'subsample': 0.004272098152680481, 'colsample_bytree': 0.9387043353739604, 'scale_pos_weight': 1.9646507030609734, 'lambda': 46.24278203665058, 'alpha': 0.7911959674594016}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:36,115] Trial 11 finished with value: 0.37840397821453936 and parameters: {'eta': 0.421402750924217, 'gamma': 1.249399312836013, 'max_depth': 5, 'min_child_weight': 0, 'max_delta_step': 11.082127783302093, 'subsample': 0.005565299334919935, 'colsample_bytree': 0.9621602593739816, 'scale_pos_weight': 1.9736528243560623, 'lambda': 49.387240773567996, 'alpha': 2.756851760983526}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:36,328] Trial 12 finished with value: 0.5749301444470755 and parameters: {'eta': 0.412859897777755, 'gamma': 0.31305393601052584, 'max_depth': 7, 'min_child_weight': 9, 'max_delta_step': 12.175390401799138, 'subsample': 0.22484558057734572, 'colsample_bytree': 0.7633238170038862, 'scale_pos_weight': 1.9896490971692642, 'lambda': 38.20665248900296, 'alpha': 0.22823904448368892}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:36,519] Trial 13 finished with value: 0.563263083116268 and parameters: {'eta': 0.5268740283115222, 'gamma': 4.224605080107296, 'max_depth': 3, 'min_child_weight': 0, 'max_delta_step': 6.587120669531792, 'subsample': 0.3173056613803439, 'colsample_bytree': 0.4306028218963033, 'scale_pos_weight': 1.6163554771297648, 'lambda': 42.70124598826717, 'alpha': 38.91360085289604}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:36,741] Trial 14 finished with value: 0.5637579919488515 and parameters: {'eta': 0.26492756822802943, 'gamma': 6.934028553844587, 'max_depth': 7, 'min_child_weight': 7, 'max_delta_step': 14.03083348445884, 'subsample': 0.14591418135391437, 'colsample_bytree': 0.782859510480866, 'scale_pos_weight': 0.7451438132964688, 'lambda': 0.21047223318476682, 'alpha': 8.906110601800034}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:36,894] Trial 15 finished with value: 0.37840397821453936 and parameters: {'eta': 0.36044475911634594, 'gamma': 10.57252901389499, 'max_depth': 3, 'min_child_weight': 11, 'max_delta_step': 7.4193922198004065, 'subsample': 0.015309417606752418, 'colsample_bytree': 0.3191517104381181, 'scale_pos_weight': 1.3963558562961969, 'lambda': 20.926630334068737, 'alpha': 29.71501640565978}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:37,101] Trial 16 finished with value: 0.5613165995737626 and parameters: {'eta': 0.5560898081145746, 'gamma': 3.764704694937317, 'max_depth': 4, 'min_child_weight': 4, 'max_delta_step': 20.61967247801251, 'subsample': 0.4226995451874907, 'colsample_bytree': 0.6479453512032516, 'scale_pos_weight': 1.8040387860453528, 'lambda': 30.850553283696172, 'alpha': 41.370411578357306}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:37,569] Trial 17 finished with value: 0.5622922093298601 and parameters: {'eta': 0.05377849548481428, 'gamma': 5.750595039456211, 'max_depth': 6, 'min_child_weight': 12, 'max_delta_step': 16.268162107339712, 'subsample': 0.20112314095665307, 'colsample_bytree': 0.8068347324724734, 'scale_pos_weight': 0.8578359303887495, 'lambda': 42.39181700258216, 'alpha': 10.835148579180874}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:37,777] Trial 18 finished with value: 0.5525432157234194 and parameters: {'eta': 0.3476714815969392, 'gamma': 14.016473640391048, 'max_depth': 8, 'min_child_weight': 3, 'max_delta_step': 8.799951469717598, 'subsample': 0.28834882773243875, 'colsample_bytree': 0.5477725093274561, 'scale_pos_weight': 1.4106527994622255, 'lambda': 32.09863580368991, 'alpha': 27.919455110562225}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:37,937] Trial 19 finished with value: 0.37840397821453936 and parameters: {'eta': 0.6359985423946504, 'gamma': 8.40713756961603, 'max_depth': 5, 'min_child_weight': 17, 'max_delta_step': 3.735147874206838, 'subsample': 0.0983684265841443, 'colsample_bytree': 0.3702566347534576, 'scale_pos_weight': 0.39301890342681567, 'lambda': 20.413396729684116, 'alpha': 39.344396904203414}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:38,282] Trial 20 finished with value: 0.5798058252427184 and parameters: {'eta': 0.12716065828846645, 'gamma': 2.7452647232758136, 'max_depth': 4, 'min_child_weight': 8, 'max_delta_step': 13.54901933709669, 'subsample': 0.46909486985201865, 'colsample_bytree': 0.9964214422965489, 'scale_pos_weight': 1.813043301429017, 'lambda': 49.80769001174721, 'alpha': 5.962921478330635}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:38,556] Trial 21 finished with value: 0.5510940089983423 and parameters: {'eta': 0.4424888534867037, 'gamma': 1.3782978087451028, 'max_depth': 6, 'min_child_weight': 0, 'max_delta_step': 10.755814443406068, 'subsample': 0.025318566749902138, 'colsample_bytree': 0.9801922713107849, 'scale_pos_weight': 1.9624950781503538, 'lambda': 48.19489255633446, 'alpha': 4.194325301501096}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:38,850] Trial 22 finished with value: 0.5617783566185176 and parameters: {'eta': 0.32148302461244666, 'gamma': 0.26406374872014793, 'max_depth': 4, 'min_child_weight': 2, 'max_delta_step': 9.432314636582678, 'subsample': 0.01894691858210661, 'colsample_bytree': 0.8908104220292777, 'scale_pos_weight': 1.957385112121506, 'lambda': 42.70604124547478, 'alpha': 0.2687894130811074}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:39,116] Trial 23 finished with value: 0.5617996684821216 and parameters: {'eta': 0.4443638824828924, 'gamma': 2.126437648780483, 'max_depth': 5, 'min_child_weight': 6, 'max_delta_step': 19.531332082288724, 'subsample': 0.1502401109859973, 'colsample_bytree': 0.743236465955541, 'scale_pos_weight': 1.7299374882900675, 'lambda': 40.287592088804075, 'alpha': 13.565286968027593}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:39,333] Trial 24 finished with value: 0.556916883731944 and parameters: {'eta': 0.5918032912322142, 'gamma': 0.07161450005409087, 'max_depth': 2, 'min_child_weight': 2, 'max_delta_step': 14.359997211477381, 'subsample': 0.1143926465640798, 'colsample_bytree': 0.8590817639862378, 'scale_pos_weight': 1.4710292960923401, 'lambda': 45.412242122378046, 'alpha': 4.618627380123771}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:39,568] Trial 25 finished with value: 0.5642197489936065 and parameters: {'eta': 0.500630321278408, 'gamma': 5.732165617725109, 'max_depth': 6, 'min_child_weight': 12, 'max_delta_step': 4.92813988474426, 'subsample': 0.2292904784672365, 'colsample_bytree': 0.7107965516376388, 'scale_pos_weight': 1.8082908507317554, 'lambda': 29.747710037391418, 'alpha': 15.929684192147446}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:39,825] Trial 26 finished with value: 0.5496400663035758 and parameters: {'eta': 0.28677613782877054, 'gamma': 3.5567841445169046, 'max_depth': 4, 'min_child_weight': 0, 'max_delta_step': 0.48596345236152416, 'subsample': 0.06116774677567832, 'colsample_bytree': 0.5117588122133698, 'scale_pos_weight': 1.9921741146932443, 'lambda': 49.89003963111778, 'alpha': 8.144248562294658}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:40,059] Trial 27 finished with value: 0.5681079801089272 and parameters: {'eta': 0.41093071730197234, 'gamma': 1.4418403236455115, 'max_depth': 8, 'min_child_weight': 9, 'max_delta_step': 11.63937506169793, 'subsample': 0.3918620416725691, 'colsample_bytree': 0.9395366062656823, 'scale_pos_weight': 1.6352986031325532, 'lambda': 34.87341417742788, 'alpha': 35.06325082859961}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:40,237] Trial 28 finished with value: 0.5666635093535402 and parameters: {'eta': 0.6807417752795553, 'gamma': 6.856942269492362, 'max_depth': 0, 'min_child_weight': 5, 'max_delta_step': 9.038585750394322, 'subsample': 0.1877971527295118, 'colsample_bytree': 0.6853319608285564, 'scale_pos_weight': 1.8674263164969462, 'lambda': 45.72023757489763, 'alpha': 2.0964306694820642}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:40,379] Trial 29 finished with value: 0.37840397821453936 and parameters: {'eta': 0.22079448402813784, 'gamma': 8.979248246145621, 'max_depth': 6, 'min_child_weight': 2, 'max_delta_step': 19.20089946194772, 'subsample': 0.0009785897008094957, 'colsample_bytree': 0.8406616755596652, 'scale_pos_weight': 0.5595580328089322, 'lambda': 17.40066758810305, 'alpha': 24.92033090693878}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:40,550] Trial 30 finished with value: 0.5686242008051148 and parameters: {'eta': 0.9284341532365534, 'gamma': 4.640287630295274, 'max_depth': 5, 'min_child_weight': 19, 'max_delta_step': 23.09022357308688, 'subsample': 0.6780737559846562, 'colsample_bytree': 0.573248330424613, 'scale_pos_weight': 1.2861936804255143, 'lambda': 39.660080871155266, 'alpha': 24.204183634034692}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:40,698] Trial 31 finished with value: 0.37840397821453936 and parameters: {'eta': 0.3675238429229402, 'gamma': 12.411170852513472, 'max_depth': 3, 'min_child_weight': 12, 'max_delta_step': 7.173736273648302, 'subsample': 0.06425253985609239, 'colsample_bytree': 0.30771795606582936, 'scale_pos_weight': 1.36628881194595, 'lambda': 21.047789834661046, 'alpha': 29.57791740685183}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:40,849] Trial 32 finished with value: 0.37840397821453936 and parameters: {'eta': 0.48820946942050547, 'gamma': 11.198188996018835, 'max_depth': 3, 'min_child_weight': 11, 'max_delta_step': 12.80723345965821, 'subsample': 0.0012472491645546951, 'colsample_bytree': 0.4242936606911061, 'scale_pos_weight': 0.92095647352496, 'lambda': 16.50418723067696, 'alpha': 44.8472362628456}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:41,108] Trial 33 finished with value: 0.4776130712763438 and parameters: {'eta': 0.1427868055641882, 'gamma': 14.073464356549204, 'max_depth': 2, 'min_child_weight': 10, 'max_delta_step': 15.798338413528477, 'subsample': 0.26372352482834027, 'colsample_bytree': 0.3473547307810957, 'scale_pos_weight': 1.6908755043325765, 'lambda': 27.879770449914446, 'alpha': 46.07687920649596}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:41,284] Trial 34 finished with value: 0.41392611887283925 and parameters: {'eta': 0.33884752753392455, 'gamma': 10.62843942073575, 'max_depth': 5, 'min_child_weight': 14, 'max_delta_step': 8.096843098530297, 'subsample': 0.15161989158947897, 'colsample_bytree': 0.18359089824128735, 'scale_pos_weight': 1.872188242799957, 'lambda': 21.75229323054704, 'alpha': 21.542288423336174}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:41,430] Trial 35 finished with value: 0.37840397821453936 and parameters: {'eta': 0.4005493710116962, 'gamma': 8.148289040592498, 'max_depth': 2, 'min_child_weight': 6, 'max_delta_step': 5.323732246987907, 'subsample': 0.06660413066449264, 'colsample_bytree': 0.49537336426591305, 'scale_pos_weight': 1.0604580544387936, 'lambda': 33.18426433319632, 'alpha': 34.68435436366688}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:41,612] Trial 36 finished with value: 0.5442789486147289 and parameters: {'eta': 0.4747641212175114, 'gamma': 13.310860336767979, 'max_depth': 4, 'min_child_weight': 18, 'max_delta_step': 10.073517378227411, 'subsample': 0.5298457322948911, 'colsample_bytree': 0.264262169691855, 'scale_pos_weight': 1.4712093912204391, 'lambda': 15.801106103214426, 'alpha': 27.784734660515042}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:41,819] Trial 37 finished with value: 0.37840397821453936 and parameters: {'eta': 0.2924482574800205, 'gamma': 15.40182987984637, 'max_depth': 3, 'min_child_weight': 22, 'max_delta_step': 3.001132407177167, 'subsample': 0.06543923350726234, 'colsample_bytree': 0.9396821172141896, 'scale_pos_weight': 1.056685038546147, 'lambda': 6.056271465975522, 'alpha': 48.110616801909195}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:42,138] Trial 38 finished with value: 0.5798105612124083 and parameters: {'eta': 0.17208701755307107, 'gamma': 1.026107835159844, 'max_depth': 8, 'min_child_weight': 14, 'max_delta_step': 11.982913781186571, 'subsample': 0.6483515292885975, 'colsample_bytree': 0.6390337054792269, 'scale_pos_weight': 1.7291655301068052, 'lambda': 23.62707301717073, 'alpha': 17.39652801386248}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:42,292] Trial 39 finished with value: 0.37840397821453936 and parameters: {'eta': 0.5852843539240669, 'gamma': 2.999141788392808, 'max_depth': 6, 'min_child_weight': 4, 'max_delta_step': 14.923181888690266, 'subsample': 0.14193494718450717, 'colsample_bytree': 0.18421803199310988, 'scale_pos_weight': 1.5471759296459617, 'lambda': 37.220480097890594, 'alpha': 41.814513204762044}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:42,540] Trial 40 finished with value: 0.5700734075301916 and parameters: {'eta': 0.22003109852515504, 'gamma': 5.861620489807651, 'max_depth': 5, 'min_child_weight': 7, 'max_delta_step': 5.783819481552303, 'subsample': 0.36842794865888656, 'colsample_bytree': 0.3701241213786102, 'scale_pos_weight': 1.9021055270543095, 'lambda': 47.15620472889559, 'alpha': 7.378274354473786}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:42,686] Trial 41 finished with value: 0.37840397821453936 and parameters: {'eta': 0.640142010390685, 'gamma': 8.574054683336774, 'max_depth': 5, 'min_child_weight': 17, 'max_delta_step': 3.725487427158041, 'subsample': 0.0952928210109027, 'colsample_bytree': 0.3597833626783455, 'scale_pos_weight': 0.30646970519040817, 'lambda': 18.550807424507912, 'alpha': 40.267822929169796}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:42,852] Trial 42 finished with value: 0.37840397821453936 and parameters: {'eta': 0.8652023602555643, 'gamma': 9.85848909197561, 'max_depth': 7, 'min_child_weight': 16, 'max_delta_step': 29.018771235098654, 'subsample': 0.04351335858727313, 'colsample_bytree': 0.3953198537435798, 'scale_pos_weight': 0.3959910401498623, 'lambda': 14.846732241125942, 'alpha': 49.826062874106356}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:43,015] Trial 43 finished with value: 0.37840397821453936 and parameters: {'eta': 0.7019038233207235, 'gamma': 11.424892864050774, 'max_depth': 5, 'min_child_weight': 19, 'max_delta_step': 2.620455153952072, 'subsample': 0.10410136571964075, 'colsample_bytree': 0.48368322403454594, 'scale_pos_weight': 0.10671835013574926, 'lambda': 20.001526840485894, 'alpha': 37.03396930928504}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:43,167] Trial 44 finished with value: 0.37840397821453936 and parameters: {'eta': 0.536028061878669, 'gamma': 19.900566696104462, 'max_depth': 4, 'min_child_weight': 24, 'max_delta_step': 8.301132079668129, 'subsample': 0.19578781586640948, 'colsample_bytree': 0.3157288707909419, 'scale_pos_weight': 0.5619544518528754, 'lambda': 23.16853203377689, 'alpha': 44.77148490775937}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:43,339] Trial 45 finished with value: 0.3959649538242955 and parameters: {'eta': 0.7852964140472163, 'gamma': 8.103581189623299, 'max_depth': 6, 'min_child_weight': 29, 'max_delta_step': 10.637973217370057, 'subsample': 0.10683735565871393, 'colsample_bytree': 0.45101950649975103, 'scale_pos_weight': 0.7358266817304668, 'lambda': 26.242991673819862, 'alpha': 33.27935773850971}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:43,565] Trial 46 finished with value: 0.553999526403031 and parameters: {'eta': 0.3810875902275936, 'gamma': 7.019399432512792, 'max_depth': 4, 'min_child_weight': 20, 'max_delta_step': 4.428850838480623, 'subsample': 0.2787920809100377, 'colsample_bytree': 0.28704374902347785, 'scale_pos_weight': 1.1376773400586995, 'lambda': 28.94854802880674, 'alpha': 37.30729046530162}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:43,736] Trial 47 finished with value: 0.37840397821453936 and parameters: {'eta': 0.4455771458867954, 'gamma': 9.407035282457604, 'max_depth': 7, 'min_child_weight': 15, 'max_delta_step': 7.276400195901413, 'subsample': 0.1557983207980668, 'colsample_bytree': 0.1918995646644309, 'scale_pos_weight': 1.3061488618066424, 'lambda': 43.60063330676023, 'alpha': 31.31846367349563}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:43,935] Trial 48 finished with value: 0.5729836609045702 and parameters: {'eta': 0.6336200507809077, 'gamma': 2.083392280293759, 'max_depth': 7, 'min_child_weight': 1, 'max_delta_step': 1.5454911685219592, 'subsample': 0.7468856574269551, 'colsample_bytree': 0.5395847019047315, 'scale_pos_weight': 0.037553986177082166, 'lambda': 24.584049358102902, 'alpha': 41.91095803242313}. Best is trial 4 with value: 0.37840397821453936.
# [I 2025-05-21 17:10:44,092] Trial 49 finished with value: 0.37840397821453936 and parameters: {'eta': 0.31593731944358294, 'gamma': 10.284290760870288, 'max_depth': 3, 'min_child_weight': 26, 'max_delta_step': 13.038114087972081, 'subsample': 0.001091929888036824, 'colsample_bytree': 0.008315189909706588, 'scale_pos_weight': 1.6507254269742975, 'lambda': 14.474908653651418, 'alpha': 20.403988748621696}. Best is trial 4 with value: 0.37840397821453936.
# Best trial parameters: {'eta': 0.40623781973319983, 'gamma': 6.0419986957095055, 'max_depth': 5, 'min_child_weight': 10, 'max_delta_step': 11.710459828187522, 'subsample': 0.14002301709572773, 'colsample_bytree': 0.46761357836748774, 'scale_pos_weight': 1.937822384427298, 'lambda': 31.268257820037277, 'alpha': 47.91599175107431}
# Best score: 0.37840397821453936

# %%
def model_predict_reg(train = X, target = y, test = testing):
    
    test_pred = 0
    scores = []

    kf = StratifiedKFold(n_splits=NUM_FOLDS, random_state=SEED, shuffle=True)
    
    params = {
        'random_state': SEED,
        'objective': 'reg:squarederror',
        'nthread': -1, 
        
        'eta': 0.24383670805100566, 
        'gamma': 0.6148174565208251, 
        'max_depth': 5, 
        'min_child_weight': 12, 
        'max_delta_step': 2.1559070673491467, 
        'subsample': 0.8383847654915885, 
        'colsample_bytree': 0.6500674760300006, 
        'scale_pos_weight': 0.8647482462747366, 
        'lambda': 10.499277990812498, 
        'alpha': 24.532310710495764    
    }


    for f, (train_idx, val_idx) in enumerate(kf.split(train, target)):
        
        X_train, X_test = train.iloc[train_idx], train.iloc[val_idx]
        y_train, y_test = target[train_idx], target[val_idx]
        
        trn_data = xgb.DMatrix(X_train, label=y_train)
        val_data = xgb.DMatrix(X_test, label=y_test)
        test_data = xgb.DMatrix(test)

        model = xgb.train(params, trn_data, num_boost_round=100)

        val_pred_data = model.predict(val_data)

        scores.append(mean_squared_error(y_test, val_pred_data.round().astype('int')))
        
        pred_data = model.predict(test_data)

        test_pred += pred_data/NUM_FOLDS

    return test_pred, np.mean(scores)

test_pred, scores = model_predict_reg()

sample_submission['quality'] = test_pred.round().astype(int)
sample_submission.to_csv('subsci_df_reg.csv', index=False)
sample_submission
# Out:
#         Id  quality
# 0     2056        5
# 1     2057        6
# 2     2058        5
# 3     2059        6
# 4     2060        6
# ...    ...      ...
# 1367  3423        6
# 1368  3424        6
# 1369  3425        5
# 1370  3426        5
# 1371  3427        6
#
# [1372 rows x 2 columns]
